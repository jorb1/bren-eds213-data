# %%
# Import libraries
import pandas as pd
import numpy as np

# %%
# Load in datasets
accessions = pd.read_excel('discussion-section/all-accn.xlsx')
localities = pd.read_excel('discussion-section/all-mesozoic.xlsx')
specimens = pd.read_excel('discussion-section/spec-meso.xlsx')
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\ProgramData\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\ProgramData\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
specimens.head()
# Out:
#    SpecNo  AccNo    Formation       LocNo                            Name  \
# 0   21047   12.0   Hell Creek  V--1994093                      Pine Cones
# 1   21048   12.0   Hell Creek  V--1994093                      Pine Cones
# 2    6511  218.0          NaN  -I-1999007  Jurassic Ferruginous Oncoliths
# 3   12773  330.0  Kaiparowits  V--2008017                Tony's Microsite
# 4   12774  330.0  Kaiparowits  V--2008017                Tony's Microsite
#
#          Field No Taxon/Full Name Element Portion  \
# 0  1993 DLL 8-9-2      Vertebrata     NaN     NaN
# 1  1993 DLL 8-9-2         Pinales     NaN     NaN
# 2             NaN        Animalia     NaN     NaN
# 3         2008-23    Ornithischia     NaN     NaN
# 4         2008-23   Hadrosauridae     NaN     NaN
#
#                         Description System/Period           Series/Epoch  \
# 0             misc. bones and shell    Cretaceous  Upper/Late Cretaceous
# ...

# %% [markdown]
# I'm going to clean the Specimens data table first!
#
# Some of these columns I drop because the variables are presented on other datatables, in a way that makes much more sense from their relationship. For example, the "Formation" columnn will be its own table, which links with the Locality table, rather than the specimen table. Other columns contain variables that aren't useful for this project.

# %%
# Drop columns
specimens = specimens.drop(columns=['Last Name', 'Storage/Full Name', 'Erathem/Era', 'Formation', 'System/Period', 'Series/Epoch', 'Name'])

# %%
specimens.head()
# Out:
#    SpecNo  AccNo       LocNo        Field No Taxon/Full Name Element Portion  \
# 0   21047   12.0  V--1994093  1993 DLL 8-9-2      Vertebrata     NaN     NaN
# 1   21048   12.0  V--1994093  1993 DLL 8-9-2         Pinales     NaN     NaN
# 2    6511  218.0  -I-1999007             NaN        Animalia     NaN     NaN
# 3   12773  330.0  V--2008017         2008-23    Ornithischia     NaN     NaN
# 4   12774  330.0  V--2008017         2008-23   Hadrosauridae     NaN     NaN
#
#                         Description
# 0             misc. bones and shell
# 1          cones of cf. Metasequoia
# 2  Growth of ferruginous oncoliths.
# 3                               NaN
# 4                               NaN

# %%
localities.head()
# Out:
#         LocNo                            Name    State           County  \
# 0  -I-2001012  Mesozoic Invertebrate Unknowns      NaN              NaN
# 1  V--2009007        England Mesozoic General      NaN              NaN
# 2  --P2001009         Mesozoic Plant Unknowns      NaN              NaN
# 3  V--2013049                Clark Metatarsal     Utah  Garfield County
# 4  V--2000007        Cretaceous Hell Creek Fm  Montana              NaN
#
#    Latitude1  Longitude1  Township  Range  Section             Subdiv  ...  \
# 0        NaN         NaN       NaN    NaN      NaN                NaN  ...
# 1        NaN         NaN       NaN    NaN      NaN                NaN  ...
# 2        NaN         NaN       NaN    NaN      NaN                NaN  ...
# 3  37.553286 -111.806867      37.0    1.0     32.0  NE1/4 NE1/4 NE1/4  ...
# 4        NaN         NaN       NaN    NaN      NaN                NaN  ...
#
#    UTM Band UTM Easting  UTM Northing  Map    Formation  Series/Epoch  \
# ...

# %%
localities = localities.drop(columns=['Township', 'Range', 'Section', 'Subdiv', 'UTM Band', 'UTM Easting', 'UTM Northing', 'Erathem/Era', 'Map', 'UTM Zone'])

# %%
localities.head()
# Out:
#         LocNo                            Name    State           County  \
# 0  -I-2001012  Mesozoic Invertebrate Unknowns      NaN              NaN
# 1  V--2009007        England Mesozoic General      NaN              NaN
# 2  --P2001009         Mesozoic Plant Unknowns      NaN              NaN
# 3  V--2013049                Clark Metatarsal     Utah  Garfield County
# 4  V--2000007        Cretaceous Hell Creek Fm  Montana              NaN
#
#    Latitude1  Longitude1  Elev (ft) Datum  UTM Zone  Map    Formation  \
# 0        NaN         NaN        NaN   NaN       NaN  NaN          NaN
# 1        NaN         NaN        NaN   NaN       NaN  NaN          NaN
# 2        NaN         NaN        NaN   NaN       NaN  NaN          NaN
# 3  37.553286 -111.806867        NaN   NaN       NaN  NaN  Kaiparowits
# 4        NaN         NaN        NaN   NaN       NaN  NaN   Hell Creek
#
#   Series/Epoch Stage/Age System/Period Erathem/Era  \
# 0          NaN       NaN           NaN    Mesozoic
# ...
